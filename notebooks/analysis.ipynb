# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
experiment_names= ['densenet121_cifar10','resnet50_cifar10','resnet50_cifar10_fixed']
my_data = {}
for experiment_name in experiment_names:
    my_data[experiment_name] = np.genfromtxt('../experiments_results/'+experiment_name+'/result_outputs/summary.csv',delimiter=',',skip_header=1)

# %%
train_acc ={}
val_acc ={}
train_error = {}
val_error = {}
for name in experiment_names:
    train_acc[name] = my_data[name][:,0]
    train_error[name] = my_data[name][:,1]
    val_acc[name] = my_data[name][:,2]
    val_error[name] = my_data[name][:,3]
epochs = my_data['resnet50_cifar10'][:,4]

# %%
plt.plot(val_acc['resnet50_cifar10'])

# %%
plt.plot(val_acc['resnet50_cifar10_fixed'])

# %%
plt.plot(val_acc['densenet121_cifar10'])
