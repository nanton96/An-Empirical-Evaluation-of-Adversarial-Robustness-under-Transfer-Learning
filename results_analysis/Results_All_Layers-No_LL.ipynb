# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
import re

# %%
def add_multicolumn(df, df2, new_col_name):
    tmp = df2.copy()    # make copy, otherwise df2 will be changed !!!
    tmp.columns = pd.MultiIndex.from_product([[new_col_name], df2.columns.tolist()])
    return pd.concat([df, tmp], axis=1)

def get_valid_filename(s):
    s = str(s).strip().replace(' ', '_')
    return re.sub(r'(?u)[^-\w.]', '', s)

# %%
model_path = '/users/Stathis/GoogleDrive/MLP/transfer_all_layers/'
nets =  list(filter(lambda x: os.path.isdir(os.path.join(model_path, x)), os.listdir(model_path)))
nets = [a for a in nets if 'resnet56' in a  or 'densenet121' in a]
nets.sort()

li = []
for net in nets:
    filename =  os.path.join(model_path, net) +'/result_outputs/test_summary.csv'
    df = pd.read_csv(filename, delimiter=",", index_col=None, header=0)
    nn = net.split('_')
    df['net'] = nn[3]
    df['source'] = nn[4]
    df['target'] = nn[5]
    df['step'] = nn[7]
    df['gamma'] = nn[9]
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.set_index(['net', 'source', 'target'])
# Out:
#                            test_acc  test_loss step gamma
# net         source target
# densenet121 fgsm   fgsm      0.9145   0.358316   25   0.1
#                    nat       0.9401   0.256466   25   0.1
#                    nat       0.9388   0.254179   25   0.1
#             nat    fgsm      0.9035   0.338362   25   0.1
#                    nat       0.9340   0.271384   25   0.1
#                    nat       0.9351   0.260235   25   0.1
#                    pgd       0.8945   0.336705   25   0.1
#             pgd    nat       0.9277   0.268576   25   0.1
#                    nat       0.9261   0.296056   25   0.1
#                    pgd       0.8938   0.357319   25   0.1
# resnet56    fgsm   fgsm      0.8929   0.356749   25   0.1
#                    fgsm      0.8906   0.370036   25   0.1
#                    nat       0.9178   0.315059   25   0.1
#                    nat       0.9189   0.355595   25   0.1
#             nat    fgsm      0.9052   0.308398   25   0.1
#                    fgsm      0.8925   0.355220   25   0.1
#                    nat       0.9303   0.307776   20   0.4
#                    nat       0.9250   0.324039   25   0.1
#                    pgd       0.8810   0.439584   25   0.1
#             pgd    nat       0.9184   0.314190   25   0.1
#                    nat       0.9128   0.355118   25   0.1
#                    pgd       0.8868   0.372155   25   0.1

# %%
import os
import json

# %% [markdown]
# # Label Leaking

# %%
model_path = '/users/Stathis/GoogleDrive/MLP/attack_results_pgd_7/'
nets =  list(os.listdir(model_path))
nets = [a for a in nets if 'all_layers' in a and 'no_LL' not in a]
nets.sort()

attack_results = {}

for net in nets:
    fname = model_path+net
    with open(fname,'r+') as json_data:
        attack_results[net[24:-5]] = list(json.load(json_data).values())
        
df = pd.DataFrame.from_dict(attack_results, columns=['Clean', 
                                                     'FGSM_0.03125', 'PGD_0.03125',
                                                     'FGSM_0.0625', 'PGD_0.0625',
                                                     'FGSM_0.125', 'PGD_0.125',                                                    
                                                    ], orient='index')
df=np.round(df*100,1)

for net in df.iterrows():
#     print(net[0])
    nn = net[0].split('_')
#     print(nn)
    df.loc[net[0],'net'] = nn[3]
    df.loc[net[0],'source'] = nn[4]
    df.loc[net[0],'target'] = nn[5]
    df.loc[net[0],'step'] = nn[7]
    df.loc[net[0],'gamma'] = nn[9]
    
df.groupby([ 'net','source', 'target', ]).mean()
# Out:
#                            Clean  FGSM_0.03125  PGD_0.03125  FGSM_0.0625  \
# net         source target
# densenet121 fgsm   fgsm    91.50         77.20        60.30        68.30
#                    nat     93.95         60.50        19.80        48.85
#             nat    fgsm    90.40         78.80        65.00        69.80
#                    nat     93.45         56.20        14.75        45.05
#                    pgd     89.40         75.40        60.50        66.40
#             pgd    nat     92.70         60.05        21.35        48.80
#                    pgd     89.40         77.60        60.30        67.20
# resnet56    fgsm   fgsm    89.20         72.65        54.95        59.80
#                    nat     91.85         60.05        22.30        48.75
#             nat    fgsm    89.90         76.75        66.10        66.30
#                    nat     92.75         58.45        16.80        46.65
#                    pgd     88.10         76.50        65.10        68.10
#             pgd    nat     91.55         61.65        21.05        51.40
#                    pgd     88.70         75.70        60.00        66.70
#
#                            PGD_0.0625  FGSM_0.125  PGD_0.125
# net         source target
# densenet121 fgsm   fgsm         36.00       54.20      13.80
#                    nat           6.85       37.90       4.00
#             nat    fgsm         41.80       53.40      17.20
#                    nat           5.70       34.95       3.80
#                    pgd          35.80       52.80      14.20
#             pgd    nat           7.90       37.40       4.75
#                    pgd          35.70       52.10      13.90
# resnet56    fgsm   fgsm         29.55       44.55      12.40
#                    nat           8.80       38.15       5.35
#             nat    fgsm         44.10       49.40      19.30
#                    nat           6.65       36.20       4.55
#                    pgd          42.90       52.90      19.30
#             pgd    nat           9.20       40.60       5.70
#                    pgd          35.80       52.30      15.30

# %% [markdown]
# # No Label Leaking

# %%
model_path = '/users/Stathis/GoogleDrive/MLP/attack_results_pgd_7/'
nets =  list(os.listdir(model_path))
nets = [a for a in nets if 'all_layers' in a and 'no_LL' in a]
nets.sort()

attack_results = {}

for net in nets:
    fname = model_path+net
    with open(fname,'r+') as json_data:
        attack_results[net[30:-5]] = list(json.load(json_data).values())
        
df = pd.DataFrame.from_dict(attack_results, columns=['Clean', 
                                                     'FGSM_0.03125', 'PGD_0.03125',
                                                     'FGSM_0.0625', 'PGD_0.0625',
                                                     'FGSM_0.125', 'PGD_0.125',                                                    
                                                    ], orient='index')
df=np.round(df*100,1)

for net in df.iterrows():
#     print(net[0])
    nn = net[0].split('_')
#     print(nn)
    df.loc[net[0],'net'] = nn[3]
    df.loc[net[0],'source'] = nn[4]
    df.loc[net[0],'target'] = nn[5]
    df.loc[net[0],'step'] = nn[7]
    df.loc[net[0],'gamma'] = nn[9]
    
# df.set_index([ 'net','source', 'target', ])

# %%
df.groupby([ 'net','source', 'target', ]).mean()
# Out:
#                            Clean  FGSM_0.03125  PGD_0.03125  FGSM_0.0625  \
# net         source target
# densenet121 fgsm   fgsm    91.50         77.20        60.30        68.30
#                    nat     93.95         60.50        19.80        48.85
#             nat    fgsm    90.40         78.80        65.00        69.80
#                    nat     93.45         56.20        14.75        45.05
#                    pgd     89.40         75.40        60.50        66.40
#             pgd    nat     92.70         60.05        21.35        48.80
#                    pgd     89.40         77.60        60.30        67.20
# resnet56    fgsm   fgsm    89.20         72.65        54.95        59.80
#                    nat     91.85         60.05        22.30        48.75
#             nat    fgsm    89.90         76.75        66.10        66.30
#                    nat     92.75         58.45        16.80        46.65
#                    pgd     88.10         76.50        65.10        68.10
#             pgd    nat     91.55         61.65        21.05        51.40
#                    pgd     88.70         75.70        60.00        66.70
#
#                            PGD_0.0625  FGSM_0.125  PGD_0.125
# net         source target
# densenet121 fgsm   fgsm         36.00       54.20      13.80
#                    nat           6.85       37.90       4.00
#             nat    fgsm         41.80       53.40      17.20
#                    nat           5.70       34.95       3.80
#                    pgd          35.80       52.80      14.20
#             pgd    nat           7.90       37.40       4.75
#                    pgd          35.70       52.10      13.90
# resnet56    fgsm   fgsm         29.55       44.55      12.40
#                    nat           8.80       38.15       5.35
#             nat    fgsm         44.10       49.40      19.30
#                    nat           6.65       36.20       4.55
#                    pgd          42.90       52.90      19.30
#             pgd    nat           9.20       40.60       5.70
#                    pgd          35.80       52.30      15.30

# %% [markdown]
# # Black box attacks

# %%
js = json.load(open("../experiments_results/attack_results/black_box_results_all_layers.json"))

# %%
js
# Out:
# {'cifar10_e_0.03125': [{'transfer_all_layers_densenet121_fgsm_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8423999999999999,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7350000000000001,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.7302999999999998,
#    'transfer_all_layers_densenet121_nat_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8525999999999998,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.6912999999999999,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.6949000000000001,
#    'transfer_all_layers_densenet121_nat_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8153,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7225,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.7249999999999999,
#    'transfer_all_layers_densenet121_pgd_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8369,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8273999999999999,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.8261000000000002,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.748,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.7406,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8469,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.835,
#    'transfer_all_layers_resnet56_nat_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7279999999999999,
#    'transfer_all_layers_resnet56_nat_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8219000000000003,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7471999999999999,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.7569000000000001,
#    'transfer_all_layers_resnet56_pgd_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8150999999999999,
#    'transfer_all_layers_resnet56_nat_nat_step_20_gamma_0.4_attacked_by_fgsm_acc': 0.7192000000000001},
#   {'transfer_all_layers_densenet121_fgsm_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8376,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.6365,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.6335000000000001,
#    'transfer_all_layers_densenet121_nat_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8473,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.5756,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.581,
#    'transfer_all_layers_densenet121_nat_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8089000000000003,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.6456000000000001,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.6522000000000001,
#    'transfer_all_layers_densenet121_pgd_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8330999999999998,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8184999999999999,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.8193999999999998,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.6951,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.6890000000000002,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8434999999999999,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.8314,
#    'transfer_all_layers_resnet56_nat_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.6436,
#    'transfer_all_layers_resnet56_nat_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8179000000000001,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.6846,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.7021999999999999,
#    'transfer_all_layers_resnet56_pgd_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8108,
#    'transfer_all_layers_resnet56_nat_nat_step_20_gamma_0.4_attacked_by_pgd_acc': 0.6304000000000001}],
#  'cifar10_e_0.06250': [{'transfer_all_layers_densenet121_fgsm_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8251,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.6412,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.6427,
#    'transfer_all_layers_densenet121_nat_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8358999999999999,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.5972,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.5975,
#    'transfer_all_layers_densenet121_nat_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8028000000000002,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.6359,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.6444000000000001,
#    'transfer_all_layers_densenet121_pgd_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8146000000000002,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8064,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.8062999999999999,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.6740999999999999,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.6720000000000002,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8321,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.8208999999999999,
#    'transfer_all_layers_resnet56_nat_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.6413000000000001,
#    'transfer_all_layers_resnet56_nat_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8103999999999998,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.6721,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.6809999999999999,
#    'transfer_all_layers_resnet56_pgd_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.8000000000000002,
#    'transfer_all_layers_resnet56_nat_nat_step_20_gamma_0.4_attacked_by_fgsm_acc': 0.6301000000000001},
#   {'transfer_all_layers_densenet121_fgsm_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8183,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.43750000000000006,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.4452999999999999,
#    'transfer_all_layers_densenet121_nat_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8287999999999998,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.36920000000000003,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.3739,
#    'transfer_all_layers_densenet121_nat_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.7927,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.48109999999999997,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.49079999999999996,
#    'transfer_all_layers_densenet121_pgd_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8068999999999998,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.7935,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.7953,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.5508000000000001,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.546,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8253999999999999,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.8134,
#    'transfer_all_layers_resnet56_nat_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.45720000000000005,
#    'transfer_all_layers_resnet56_nat_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.8011000000000001,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.5324,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.5471,
#    'transfer_all_layers_resnet56_pgd_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.7938999999999998,
#    'transfer_all_layers_resnet56_nat_nat_step_20_gamma_0.4_attacked_by_pgd_acc': 0.4393000000000001}],
#  'cifar10_e_0.12500': [{'transfer_all_layers_densenet121_fgsm_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7619999999999999,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.5114000000000001,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.5152,
#    'transfer_all_layers_densenet121_nat_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7737999999999999,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.4592000000000001,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.4648999999999999,
#    'transfer_all_layers_densenet121_nat_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7731999999999999,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.5015,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.5061,
#    'transfer_all_layers_densenet121_pgd_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7467,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7569,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.7613000000000001,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.5458000000000001,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.557,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7995000000000002,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.7882999999999999,
#    'transfer_all_layers_resnet56_nat_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.5003,
#    'transfer_all_layers_resnet56_nat_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7771000000000001,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.5473000000000001,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_2_attacked_by_fgsm_acc': 0.5638000000000001,
#    'transfer_all_layers_resnet56_pgd_pgd_step_25_gamma_0.1_attacked_by_fgsm_acc': 0.7664,
#    'transfer_all_layers_resnet56_nat_nat_step_20_gamma_0.4_attacked_by_fgsm_acc': 0.4919},
#   {'transfer_all_layers_densenet121_fgsm_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.7624,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.22219999999999998,
#    'transfer_all_layers_densenet121_fgsm_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.2241,
#    'transfer_all_layers_densenet121_nat_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.784,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.17309999999999998,
#    'transfer_all_layers_densenet121_nat_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.17949999999999997,
#    'transfer_all_layers_densenet121_nat_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.7550999999999999,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.27,
#    'transfer_all_layers_densenet121_pgd_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.2798,
#    'transfer_all_layers_densenet121_pgd_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.7382000000000001,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.733,
#    'transfer_all_layers_resnet56_fgsm_fgsm_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.7417999999999999,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.33980000000000005,
#    'transfer_all_layers_resnet56_fgsm_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.3497,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_attacked_by_pgd_acc': 0.7877999999999998,
#    'transfer_all_layers_resnet56_nat_fgsm_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.7734999999999999,
#    'transfer_all_layers_resnet56_nat_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.2274,
#    'transfer_all_layers_resnet56_nat_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.7645000000000002,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_attacked_by_pgd_acc': 0.3282999999999999,
#    'transfer_all_layers_resnet56_pgd_nat_step_25_gamma_0.1_2_attacked_by_pgd_acc': 0.3338999999999999,
#    'transfer_all_layers_resnet56_pgd_pgd_step_25_gamma_0.1_attacked_by_pgd_acc': 0.7558999999999999,
#    'transfer_all_layers_resnet56_nat_nat_step_20_gamma_0.4_attacked_by_pgd_acc': 0.22099999999999997}]}
